# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
car=pd.read_csv('car data.csv')
car.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
car.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Selling_type Transmission  Owner
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0

# %%
car.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
car.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# Import necessary libraries from scikit-learn
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
train, test= train_test_split(car,test_size=0.3)
print(train.shape)
print(test.shape)
# Out:
# (210, 9)
# (91, 9)

# %%
features = ['Present_Price','Driven_kms','Fuel_Type','Selling_type','Transmission']
train_X=train[features]
train_y=train.Selling_Price
test_X=test[features]
test_y=test.Selling_Price

# %%
train_X.head()
# Out:
#      Present_Price  Driven_kms Fuel_Type Selling_type Transmission
# 72           18.61       56001    Petrol       Dealer       Manual
# 111           1.50        8700    Petrol   Individual       Manual
# 264           7.00       40026    Petrol       Dealer       Manual
# 290           6.40       19000    Petrol       Dealer       Manual
# 50           30.61      104707    Diesel       Dealer    Automatic

# %%
test_X.head()
# Out:
#      Present_Price  Driven_kms Fuel_Type Selling_type Transmission
# 141           0.80       20000    Petrol   Individual       Manual
# 275          13.60       30753    Petrol       Dealer    Automatic
# 251           9.90       56701    Petrol       Dealer       Manual
# 221           6.79       32000    Petrol       Dealer    Automatic
# 63           35.96       47000    Diesel       Dealer    Automatic

# %%
train_X['Fuel_Type'] = train_X['Fuel_Type'].astype('category')
test_X['Fuel_Type'] = test_X['Fuel_Type'].astype('category')
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
train_X['Fuel_Type'] = le.fit_transform(train_X['Fuel_Type'])
test_X['Fuel_Type'] = le.transform(test_X['Fuel_Type'])
# Out:
# <ipython-input-56-f1f26ce64d5d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_X['Fuel_Type'] = train_X['Fuel_Type'].astype('category')
# <ipython-input-56-f1f26ce64d5d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_X['Fuel_Type'] = test_X['Fuel_Type'].astype('category')
# <ipython-input-56-f1f26ce64d5d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
train_X['Selling_type'] = train_X['Selling_type'].astype('category')
test_X['Selling_type'] = test_X['Selling_type'].astype('category')
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
train_X['Selling_type'] = le.fit_transform(train_X['Selling_type'])
test_X['Selling_type'] = le.transform(test_X['Selling_type'])
# Out:
# <ipython-input-57-c9106e21c748>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_X['Selling_type'] = train_X['Selling_type'].astype('category')
# <ipython-input-57-c9106e21c748>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_X['Selling_type'] = test_X['Selling_type'].astype('category')
# <ipython-input-57-c9106e21c748>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
train_X['Transmission'] = train_X['Transmission'].astype('category')
test_X['Transmission'] = test_X['Transmission'].astype('category')
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
train_X['Transmission'] = le.fit_transform(train_X['Transmission'])
test_X['Transmission'] = le.transform(test_X['Transmission'])
# Out:
# <ipython-input-58-7b26b9b72a80>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_X['Transmission'] = train_X['Transmission'].astype('category')
# <ipython-input-58-7b26b9b72a80>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_X['Transmission'] = test_X['Transmission'].astype('category')
# <ipython-input-58-7b26b9b72a80>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score
# Create instances of the models
linear_regression_model = LinearRegression()

# Fit the models
linear_regression_model.fit(train_X, train_y)

# Make predictions
linear_regression_predictions = linear_regression_model.predict(test_X)


# Since linear regression is not typically used for classification,
# we'll convert its continuous output to class labels


# Evaluate the models
linear_regression_mse = mean_squared_error(test_y, linear_regression_class_predictions)
linear_regression_r2= r2_score(test_y, linear_regression_class_predictions)

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=10, random_state=0, oob_score=True)

# Fit the regressor with x and y data
regressor.fit(train_X, train_y)

predictions= regressor.predict(test_X)
random_forest_mse = mean_squared_error(test_y, predictions)
random_forest_r2= r2_score(test_y, predictions)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:583: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(

# %%
print(f'Linear Regression MSE: {linear_regression_mse:.2f}')
print(f'Linear Regression R2: {linear_regression_r2:.2f}')
# Out:
# Linear Regression MSE: 11.77
# Linear Regression R2: 0.64

# %%
print(f'Random Forest MSE: {random_forest_mse:.2f}')
print(f'Random Forest R2: {random_forest_r2:.2f}')
# Out:
# Random Forest MSE: 3.15
# Random Forest R2: 0.90

# %%
results = pd.DataFrame({
    'Model': ['Linear Regression','Random Forest Regressor'],
    'Mean Squared Error': [11.77, 3.15],
    'R2 Score': [0.64,0.90]})

result_df = results.sort_values(by='R2 Score', ascending=False)
result_df.head(9)
# Out:
#                      Model  Mean Squared Error  R2 Score
# 1  Random Forest Regressor                3.15      0.90
# 0        Linear Regression               11.77      0.64
